# %% [markdown]
# # წარმოებული - მრავალცვლადიანი ფუნქციები.

# %% [markdown]
# Მოდი, გავიხსენოთ, რაში გვჭირდებოდა ორ განზომილებაში მხები წრფე და ვცადოთ მხების აგება სამ განზომილებაშიც.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ანალოგიური პრინციპი გვექნება სამ განზომილებაში - იმ განსხვავებით, რომ მხები წრფის ნაცვლად გვექნება მხები სიბრტყე - გავაანალიზოთ, რატომ და როგორ შეიძლება მისი გამოსახვა:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# რა თქმა უნდა, ამ მხებ სიბრტყესაც აქვს თავისი ფუნქცია - რაში შეიძლება ის დაგვჭირდეს და როგორ უნდა გამოვიყვანოთ ეს ფუნქცია?
#
#
# Ფუნქციის მხების სიბრტყის გამოთვლა სწორედ ფუნქციის კერძო წარმოებულებით შეგვიძლია.

# %% [markdown]
# # გრადიენტი

# %% [markdown]
#  მრავალცვლადიანი ფუნქციის გრადიენტი, რომელიც აღინიშნება
# # ∇f-ით,
#  მისი კერძო წარმოებულის ინფორმაციას ათავსებს ვექტორში:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# თუ წარმოიდგინეთ f-ის არგუმენტის სივრცეში (x0,y0,..) წერტილზე დგომას, ∇f(x0, y0..)  ვექტორი გვეუბნება, რა მიმართულებით უნდა ვიმოძრავოთ, რომ f-ის მნიშვნელობა ყველაზე სწრაფად გაიზარდოს.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Დავუბრუნდეთ ჩვენი მოგების ფუნქციას, რომლის მაქსიმიზაციაც ვცადეთ წინა ლექციაზე - მაშინ გქვონდა მხოლოდ 1 ცვლადი, რომელიც იყო ერთეულის ფასი. Რეალურ ცხოვრებაში რა თქმა უნდა მეტი ცვლადი გვექნებოდა, წარმოვიდგინოთ რომ ორი ცვლადი გვქონდა და ჩვენი ფუნქციის გრაფიკიც იყო სამგანზომილებიანი , მაგალითად ასეთი :

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ჩვენი მიზანი იგივეა , გვინდა მაქსიმალური მნიშვნელობის წერტილის პოვნა
# Ანუ აი ამის

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Როგორი იქნება ასეთი წერტილის მხები სიბრტე ? ესეც ანალოგიურია ორგანზომილებიანი სიბრტყის, ყველაზე მაღალ წერრტილზე მხები სიბრტყე იქნება ესეთი, არსაით არ იქნება გადახრილი

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# რას ნიშნავს არსაით რომ არ იქნება გადახრილი? Კერძო წარმოებულები, როგორც უკვე ვთქვით, გვიჩვენებს დახრილობას ამა თუ იმ საკოორდინატო ღერძის მიმართ, იგივენაირად, როგორც ორგანზომილებაში. Თუ დახრილი არ არის, რას ნიშავს ეს - Იმას , რომ დახრილობა არის ნულის ტოლი. Ესეიგი, კერძო წარმოებული არის 0 -ის ტოლი.
# Შესაბამისად, ფუნქციის მინიმუმის და მაქსიმუმის გამოთვლისთვის ჩვენთვის საინტერესოა ისეთი წერტილები, რომლისთვისაც კერძო წარმოებულები არის 0.

# %% [markdown]
# ## df/dy (x0, y0) = 0
# ## df/dx (x0, y0) = 0
#  Რამდენი ცვლადიც არ უნდა გვქონდეს ეს იქნება ჭეშმარიტი მაქსიმუმ/მინიმუმ წერტილებისთვის.

# %% [markdown]
# Მაგრამ როგორც ორ განზომილებაში შეიძლებოდა უბრალოდ შემაღლებების წერტილები ყოფილიყო სადაც მხები სწორი გვქონდა: ![image.png](data:image/png;base64,...)

# %% [markdown]
# აქაც ანალოგიური სიტუაციაა:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# და მხები "არა-დახრილი" იქნება ამ წერტილებისთვისაც, შესაბამისად, კიდევ დაგვჭირდება რაღაცების გაკეთება, რომ ამოვარჩიოთ არა ეს პატარა შემაღლებული წერტილები, არამედ ნამდვილი მაქსიმუმი,
# ზუსტად ანალოგიური სიტუაცია გვქონდა ორ განზომილებაშიც.
#
# აქაც დაგვჭირდება **მეორე რიგის კერძო წარმოებულის ტესტი**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. H < 0 ნიშნავს რომ (x0, y0) უნაგირა წერტილია.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. H > 0
#
#    ა) თუ fxx(x0,y0) < 0 მაშინ (x0, y0) არის ლოკალური მაქსიმუმის წერტილი
#    ![image.png](data:image/png;base64,...)
#
#    ბ)თუ fxx(x0,y0) > 0 მაშინ (x0, y0) არის ლოკალური მინიმუმის წერტილი ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. H = 0 - არ გვაქვს საკმარისი ინფორმაცია.
