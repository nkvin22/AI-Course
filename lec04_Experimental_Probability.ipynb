# %% [markdown]
# ---
# ### თეორიული VS ექსპერიმენტული ალბათობა

# %% [markdown]
# ოდნავ გავცდეთ მონეტებს, კამათლებს და ბანქოს და წარმოვიდგინოთ, რომ ფეხბურთს უყურებთ

# %% [markdown]
# Ასევე, წარმოვიდგინოთ, რომ ფეხბურთის არაფერი გაგეგებათ, და მხოლოდ ის იცით, რომ ან წითელმა გუნმდა უნდა გაიმარჯვოს ან ლურჯმა გუნდმა (ფრე ვერ დამთავრდება); რა იქნებოდა თქვენთვის წითელი გუნდის გამარჯვების ალბათობა მხოლოდ ამ ინფორმაციით?

# %% [markdown]
# ლოგიკურად, 50 %.
#
# Ახლა ვთქვათ, შეგატყობინეს, რომ წითელი გუნდი ბოლო მსოფლიო ჩემპიონია და ლურჯ გუნდს რამდენიმე TOP მოთამაშე არ ჰყავს; როგორ შეიცვლებოდა ამ შემთხვევაში თქვენი პროგნოზი?

# %% [markdown]
# ლოგიკური იქნება, რომ თქვენი პროგნოზი შეიცვალოს და წითელი გუნდის მოგებისკენ გადაიხაროთ, თუნდაც 51 %ით.

# %% [markdown]
# Თამაშის დასრულებამდე 5 წუთია დარჩენილი და ლურჯი გუნდი იგებს - შეიცვლება თუ არა ამ შემთხვევაში თქვენი მიმდინარე პროგნოზი ?
#
# წესით, უნდა შეიცვალოს.

# %% [markdown]
# Ნიშნავს თუ არა ეს იმას, რომ თქვენი თავდაპირველი პროგნოზი არასწორი იყო?
#
# **არა**

# %% [markdown]
# 💡Მხოლოდ დამდგარი შედეგი ვერ გვიჩვენებს, იყო თუ არა ალბათობა არასწორად განსაზღვრული.
#
# 💡Როდესაც ჩვენ ვიგებთ ახალ ინფორმაციას, ჩვენ უნდა გვქონდეს მზაობა ჩვენი პროგნოზის შესაცვლელად.

# %% [markdown]
# Თეორიულია ალბათობაა, როცა ვამბობთ, რომ კამათლის გაგორებისას 5იანის ამოსვლის ალბათობა ⅙-ია. Ეს ისეთი “
# “Პრიმიტიული” ამოცანაა, რომელშიც სხვა გარე ფაქტორები არ მონაწილეობს და შეგვიძლია ფორმულით ვიხელმძღანელოთ, ასეთი პრიმიტიული ამოცანებია მაგალითად კამათლის გაგორების ან მონეტის აგდების შესაძლო შედეგების და მათი ალბათობების დათვლა: მაგ. დარწმუნებით შეგვიძლია ვთქვათ, რომ კამათელზე 5-იანის მოსვლის ალბათობა 1/6-ია, მაგრამ ნიშნავს თუ არა ეს იმას, რომ 6-ჯერ რომ გავაგოროთ კამათელი, აუცილებლად 1-ხელ ამოვა 5-იანი? Ან ის, რომ მონეტის აგდებისას საფასურის ამოსვლის ალბათობა არის ½, ნიშნავს თუ არა იმას რომ 10 აგდებიდან 5 საფასური ამოვა? -ცხადია, არა, ეს უბრალოდ გვიჩვენებს იმას, თუ რამდენად ალბათურია ამა თუ იმ შედეგის დადგომა, და რომ ძალიან ბევრი ექსპერიმენტის ჩატარების შემთხვევაში, ყოველთვის ამ თანაფარდობასთან მივალთ:

# %% [markdown]
# **დიდ რიცხვთა კანონი** - ეს კანონი საფუძვლად უდევს მათემატიკურ სტატისტიკას. დიდ რიცხვთა კანონის თანახმად, **შერჩევითი მახასიათებლები ცდების (ექსპერიმენტების) რიცხვთა ზრდისას უახლოვდება თეოირიულ მახასიათებელს** , რაც საშუალებას იძლევა, ამა თუ იმ რეალური მოვლენის ალბათური მოდელების პარამეტრები შევაფასოთ ცდების მიერ მიღებული შედეგების გამოყენებით.

# %% [markdown]
# ცხადია, ჩვენთვის ცნობილი თეორიული ალბათობებიც უამრავი დაკვირვების და ექსპერიმენტის შედეგია. მაგ. მე-18 საუკუნეში ბუნებისმეტყველმა ბიუფონმა მონეტა ააგდო 4040-ჯერ, საიდანაც გერბი მოვიდა 2048-ჯერ, მე-20 საუკუნის დასაწყისში მათემატიკოსმა პირსონმა მონეტა ააგდო 24 000-ჯერ, საიდანაც გერბი მოვიდა 12 012-ჯერ. შესაბამისად, მიუხედავად იმისა, რომ მონეტის მრავალჯერადი აგდების შედეგები შემთხვევითი ხდომილებაა, მონეტის მრავალჯერადი აგდების შედეგები ობიექტურ კანონს ემორჩილება.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://flipsimu.com/ - ეს არის მონეტის აგდების სიმულატორი, სადაც შეგიძლიათ, რომ თქვენც ძალიან ბევრჯერ "ააგდოთ მონეტა". Ბევრჯერ აგდების შემთხვევაში თქვენი თანაფარდობა უნდა მიუახლოვდეს ½-ს.

# %% [markdown]
# თუმცა, რეალურ ცხოვრებაში, ნაკლებად გვჭირდება და გვაინტერესებს ხოლმე ისეთი ალბათობების გამოთვლა, რომელიც შეგვიძლია მარტივი ფორმულის გამოყენებით დავითვალოთ. კომპლექსური რეალური ამოცანების გადასაჭრელად, განმარტებითი ფორმულების გარდა, საფუძვლიანი სტატისტიკური ანალიზი/ექსპერიმენტები შეიძლება დაგვჭირდეს.
#
# მარტივი მაგალითისთვის, წარმოვიდგინოთ, რომ გვინდა დავადგინოთ, ხვიჩა კვარაცხელია გოლს გაიტანს თუ არა შემდეგ მატჩში.
#
# ![image.png](data:image/png;base64,...) სამწუხაროდ თუ საბედნიეროდ, ამის გამოთვლა რაიმე ფორმულის გამოყენებით შეუძლებელია. რაიმე სახის პროგნოზის გასაკეთებლად, სულ მინიმუმ, საჭირო იქნება თამაშების სტატისტიკა: მაგალითად, თუ ავიღებთ 20 თამაშის შედეგს, და დავინახავთ, რომ მან 15 თამაშში გაიტანა და 5ში ვერა, დაახლოებით ვიტყვით რომ 15/20 = ⅗ ია ალბათობა რომ შემდეგ მატჩში გაიტანს, მაგრამ ეს პროგნოზი ძალიან სუსტი იქნება - რატომ? რადგან მხოლოდ ეს მონაცემები საკმარისი არ არის რეალისტური პროგნოზის გასაკეთებლად და მოედანზე უამრავი სხვა ფაქტორი მოქმედებს, რომელსაც მონეტის წიბოზე გაჩერების მსგავსად ვერ დავაიგნორებთ.

# %% [markdown]
# ან თუნდაც, გვინდა საქართველოს და ესპანეთის  ფეხბურთის მატჩის შედეგის წინასწარმეტყველება -  Რა მონაცემები მოგვცემდა კარგი პროგნოზის გაკეთების შესაძლებლოას საქართველოსთვის?
#
#  ა) შედეგების პროცენტული თანაფარდობა საქართველოს და ესპანეთს შორის ჩატარებული თამაშების
#
#  ბ) საქართველოს ყველა მატჩის შედეგების მიხედვით პროცენტული თანაფარდობა
#
#  გ) არცერთი არ იქნებოდა საკმარისი

# %% [markdown]
# Მოგვცეს მონაცემები, ესპანეთი ვს საქართველო ბოლო ათი წლის განმავლობაში. Სულ 7 თამაში - შეგვიძლია თუ არა პროგნოზის გაკეთება?

# %% [markdown]
# ჩვენი პროგნოზი მხოლოდ ამ მონაცამებზე დაყრდნობით, ისევ ძალიან სუსტი იქნება.

# %% [markdown]
# მოდი შემოვიტანოთ დამატებითი "ინსტრუმენტი", იმის მსგავსი, რომელიც ზემოთ გვქონდა მონეტის აგდების სიმულაციისთვის - Ვთქვათ, გვაქვს პროგრამა, რომელსაც შეუძლია თამაშის სიმულაცია.
#
# სასარგებლო იქნება თუ არა, Რომ ჩავატაროთ კომპიუტერული სიმულაცია, სადაც ორივე გუნდს ექნება გატანის თანაბარი ალბათობა ყოველ წუთს და საბოლოო ანგარიში 90 წუთის შემდეგ მიიღება? რამდენად დაგვეხმარება ასეთი სიმულაციის ბევრჯერ გაშვება რეალისტური პროგნოზის გასაკეთებლად?

# %% [markdown]
# მსგავსი სიმულაცია არ იქნება სასარგებლო, სულ მცირე Იმიტომ, რომ გატანის ალბათობა თანაბარი არ არის. არსებობს სხვადასხვა ფაქტორები, რომელიც შესაძლოა, ამ ალბათობას განსაზღვრავდეს და, ასევე, ცვლიდეს ყოველი მომენტისთვის  - შესაბამისად, სულ მცირე, გვჭირდება დამატებითი ინფორმაცია - ანუ მონაცემები, რომლის მიხედვითაც შევძლებთ ამ ალბათობის კორექტირებას ((Მაგალითად საქართველოს თუ გატანის ალბათობას 1ზე “დავუყენებთ” და ესპანეთს 0-ზე სულ საქართველო მოიგებს ყველა სიმულაციას)). ერთ-ერთი გზა ალბათობის გამოსათვლელად იქნებოდა გასული თამაშების მიხედვით გოლის გატანის ალბათობის გამოთვლა, თუმცა ეს იგივე იქნებოდა, რომ პირდაპირ გასული 7 თამაშის შედეგის მიხედვით გამოგვეთვალა შემდეგი მატჩის პროგნოზი.
#
#  Რა უნდა ვქნათ რომ ჩვენი სიმულაცია და პროგნოზი მაქსიმალურად მივაახლოვოთ რეალობასთან?

# %% [markdown]
# გვიშველის თუ არა აქ რაიმე კომპლექსური მათემატიკური მოდელირება, ან ზემოთ აღწერილი სიმულაციის ბევრჯერ ჩატარება?

# %% [markdown]
# სინამდვილეში, როდესაც მხოლოდ ეს ინფორმაცია გვაქვს, ვერანაირი კომპლექსური მათემატიკა და ვერც მილიონი, მილიარდი სიმულაცია ვერ გვიშველის - რადგან არსობრივად არაფერი შეიცვლება, და ჩვენი მთელი პროგნოზი იმ გამოთვლილ ალბათობას დაეყრდნობა, რომელიც წარსული მატჩების გატანილი გოლების რაოდენობის მიხედვით დავითვალეთ - ანუ მხოლოდ ეს იქნება ინფორმაციის წყარო, რომლითაც თუნდაც სიმულაციის მოდელი იხელმძღვანელებს.
#
#  “გამოსავალი”/პროგნოზის გაუმჯობესების გზა მონაცემების უფრო დეტალურ ანალიზშია - ისეთი ფაქტორების, როგორიცაა მაგალითად, ფეხბურთელების ტრამვები, ამინდი, გუნდის შემადგენლობა და სხვა მრავალი ფაქტორი, რომელიც სინამდვილეში გავლენას ახდენს მატჩის შედეგზე. იმ გზებს, თუ როგორ შეიძლება მსგავსი ინფორმაციები მოვიძიოთ, დავამუშავოთ, და პროგნოზირებისთვის გამოვიყენოთ ჩვენს კურსში მოგვიანებით გავეცნობით.
