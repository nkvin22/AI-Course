# %% [markdown]
# მოდით, დროში ვიმოგზაუროთ - კაცობრიობის ურთიერთობა მონაცემებთან ამ ტერმინის გამოგონებამდე ბეევრად ადრე დაიწყო. ეს არის ამბავი ჩვენი თანდაყოლილი ცნობისმოყვარეობის, შევიცნოთ და გვესმოდეს ჩვენს გარშემო არსებული სამყარო :
# 	ძველ დროში ბაბილონელებისა და ეგვიპტელების მსგავსი ცივილიზაციები  აკვირდებოდნენ ვარსკვლავებს, არა მხოლოდ ვიზუალური სილამაზისთვის, არამედ პრაქტიკული მიზნებისთვის - ისინი ზედმიწევნით აღრიცხავდნენ ციური სხეულების მოძრაობას, იყენებდნენ ამ მონაცემებს სოფლის მეურნეობაში - წყალდიდობის პროგნოზირებისთვის, ოკეანეში ნავიგაციისთვის და ა.შ.
#
#  ![image.png](data:image/png;base64,...)
#  ეს შეგვიძლია მონაცემთა ანალიზის უპირველეს ფორმად მივიჩნიოთ - მონაცემებზე დაკვირვება, განაალიზება და გადაწყვეტილებების მიღება.

# %% [markdown]
# გადავხტეთ რენესანსის ეპოქაში - განმანათლებლობის და მეცნიერული აღმოჩენების პერიოდი - ლეონარდო და ვინჩი, გალილეო გალილეი - რას აკეთებდა ეს ხალხი? - აკვირდებოდნენ, ზომავდნენ და აღბეჭდავდნენ სამყაროს ზედმიწევნითი დეტალიზაციით, რაში მდგომარეობდა მათი მეთოდოლოგია ? - მონაცემთა შეგროვება, ჰიპოთეზის ფორმირება და პროგნოზის ტესტირება.![image.png](data:image/png;base64,...)

# %% [markdown]
# პ.ს.: თუ ხელოვნური ინტელექტიც დღევანდელი ეპოქის შემოქმედება გგონიათ , მოდი ისევ წარსულში დავბრუნდეთ და გავიხსენოთ უძველესი მითები და ლეგენდები, რომლებშიც უსულო საგნები ადამიანის მსგავსი ინტელექტით ცოცხლდებიან  ![image.png](data:image/png;base64,...)

# %% [markdown]
# მე-17 საუკუნე, ლაიბნიცი.
# ლაიბნიცმა წარმოიდგინა სამყარო, სადაც დებატები შეიძლება გადაწყდეს გამოანგარიშებით - მან შემოგვთავაზა სისტემა (ორობითი) რომელშიც მთელი ადამიანური ცოდნა შეიძლება წარმოდგენილი იყოს უნივერსალური სიმბოლოებით, რაც საშუალებას მოგვცემს ნესბიემირი პრობლემა ლოგიკური დედუქციის საშუელბით გადაწყდეს - ლაიბნიცის ეს კონცეფცია ფაქტობნრივად წინამორბედია იდეისა, რომ ადამიანის აზროვნება შეიძლება მექანიზებული იყოს.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# გადავინაცვლოთ მე-20 საუკუნეში:  ეს ეპოქა შეგვიძლია აღვიქვათ როგორც კვანტური ნახტომი მონაცემთა შეგროვებისა და ანალიზის შესაძლებლობებში - რისი შესაძლებლობა მოგვცა კომპიუეტერებმა? ის, რის გამოთვლასაც ოდესღაც წლები სჭირდებოდა, ახლა შეგვიძლია წამებში დავითვალოთ. ამ ეპოქამ შექმნა თანამედროვე კომპიუტერული და მონაცემთა მეცნიერებების სფერო, ტექნოლოგიები, რომელიც შეგვიძლია ადამიანის გენომის გაშიფრისთვის, კლიმატის ცვლილების პროგნოზირებისთვის, და სამყაროს ბევრი საიდუმლოების შესასწავლად გამოვიყენოთ -
# უძველესი ასტრონომებიდან დღევანდელ მონაცემთა მეცნიერებამდე ძიების პრინციპი იგივე რჩება, რაც შეიცვალა არის -  მასშტაბი, სიჩქარე და სიზუსტე.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# მე-20 საუკუნე: ხელოვნური ინტელექტის, როგორც სფეროს ჩამოყალიბება - 1950 წელი, “computing machinery and intelligence” ![image.png](data:image/png;base64,...)

# %% [markdown]
# ამ ნაშრომში ტურინგმა შემოგვთავაზა ის, რასაც ახლა ვუწოდებთ “ტურინგის ტესტს” - მანქანის ინტელექტის კრიტერიუმს, შეიძლება ითქვას რომ ხელოვნური ინტელექტის ტერმინი თანამედროვე სახით სწორედ ამ მომენტიდან წარმოიშვა.

# %% [markdown]
# შემდეგი ათწლეულები ტემპი არც ისეთი მაღალი იყო, სამყაროში მიმდინარე მოვლენების და ფინანსური გამოწვევების გამო. მიუხედავად ამისა, კაცობრიობამ ბევრი გარღვევა განახორციელა ხელოვნური ინტელექტის, მანქანური სწავლების, ადამიანური ნეირონული ქსელის ანალოგიის შექმნის მიმართულებიტ - დღეს ეს აღარ არის მითოლოგიური ოცნება, ეს არის პრაქტიკული რეალობა - ჩვენ გვყავს კომპიუტერები,, რომლებიც მართავენ მანქნებს, იმარჯვებენ რთულ თამაშებში, ეხმარებიან მკვლევარებს სამედიცინო კვლევებში- დღეს ეს უკვე ჩვენი ყოველდღიურობის განუყოფელი ნაწილია და ჩვენ მომავალსაც დიდწილად ეს პროცესები განაპირობებს.

# %% [markdown]
# განვმარტოთ ძირითადი ტერმინოლოგია, როლები/პასუხისმგებლობები AI/Data Science ინდუსტრიაში.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Artificial Intelligence (AI):
#
# კომპიუტერული მეცნიერების დარგი, რომელიც მიზნად ისახავს შექმნას სისტემები, რომლებსაც შეუძლიათ შეასრულონ ამოცანები, რომლებიც, როგორც წესი, მოითხოვს ადამიანის ინტელექტს.

# %% [markdown]
# ---
#
#
#
# Data Science:
#
# მონაცემთა მეცნიერება არის მულტიდისციპლინარული სფერო, რომელიც დიდი რაოდენობით მონაცემების გასაანალიზებლად აერთიანებს პრინციპებსა და პრაქტიკებს მათემატიკის, სტატისტიკის, ხელოვნური ინტელექტის კომპიუტერული ინჟინერიის სფეროებიდან.  ეს ანალიზი საჭიროა მონაცემებში არსებული კანონზომიერებების დასადგენად, აღმოჩენების გასაკეთებლად, პროგნოზირებისთვის და გადაწყვეტილებების მისაღებად.

# %% [markdown]
# ---
#
#
# Data Engineering - The Foundation
#
# მონაცემთა ინჟინერია მოიცავს სისტემების დიზაინს და იმპლემენტაციას მონაცემთა შეგროვების, შენახვისა და ანალიზისთვის, მონაცემთა დამუშავების ტექნოლოგიების პრაქტიკულ გამოყენებაზე.
#
# მონაცემთა ინჟინერია ქმნის მონაცემთა ინფრასტრუქტურას (როგორიცაა მონაცემთა ბაზები და ფართომასშტაბიანი დამუშავების სისტემები), რომელიც მონაცემთა მეცნიერებას სჭირდება ანალიზისა და მოდელირების შესასრულებლად. ის უზრუნველყოფს მონაცემების ხელმისაწვდომობას, “სისუფთავეს” და სტრუქტურიზაციას.

# %% [markdown]
# ---
#
#
# Data Analytics - The Process of Deriving Insight
#
# მონაცემთა ანალიტიკა მოიცავს მეთოდებს, რომლებიც გამოიყენება მონაცემების გასაანალიზებლად. ეს გულისხმობს სპეციალიზებული სისტემებისა და პროგრამული უზრუნველყოფის გამოყენებას მონაცემთა ანალიზისთვის, რაც საჭიროა გადაწყვეტილებების მისაღებად, ბიზნეს ამოცანების გადასაჭრელად და შემდეგი ნაბიჯების განსასაზღვრად.

# %% [markdown]
# ---
#
#
# Machine Learning (ML) - A Core Technique of AI
#
# ML არის ხელოვნური ინტელექტის ძირითადი ქვედარგი, რომელიც აძლევს სისტემებს შესაძლებლობას ავტომატურად ისწავლონ და  განვითარდნენ არსებულ გამოცდილებაზე დაყრდნობით. ML გამოიყენება ისეთი ამოცანებისთვის, როგორიცაა პროგნოზირება, კლასიფიკაცია და მონაცემების კანონზომიერებების ამოცნობა.
#
# *ML მოდელები არის ინსტრუმენტები, რომლითაც AI-ს შესაძლებლობები რეალიზდება.*

# %% [markdown]
# ---
#
#
#
#  Model -  The Output of ML
#
#  ML-ში მოდელი არის სასწავლო პროცესის შედეგი და შეიძლება განისაზღვროს, როგორც რეალურ სამყაროში პროცესის მათემატიკური წარმოდგენა. მოდელები გაწვრთნილი არიან პროგნოზების გასაკეთებლად ან მონაცემთა კლასიფიკაციისთვის, მონაცემების საფუძველზე.

# %% [markdown]
# ---
#
#
# Model Training
#
# მოდელის "გაწვრთნის" პროცესი ე.წ. "სასწავლო" მონაცემებზე (training data), რომლის დროსაც რეგულირდება პარამეტრები და კონფიგურაციები კონკრეტული ამონაცის ჭრილში, რათა მინიმუმამდე დავიდეს განსხვავება მოდელის პროგნოზებსა და რეალურ შედეგებს შორის. ეს პროცესი ხშირად განმეორებადია და ბევრ იტერაციას მოითხოვს. საბოლოო მიზანი არის ისეთი მოდელის შემუშავება, რომელიც მისთვის უცნობ მონაცემზეც შეძლებს გადაწყვეტილებების მიღებას და  პროგნოზების გაკეთებას.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# იმისთვის რომ ამ უწყვეტი ინოვაციების პროცესს ფეხი ავუწყოთ და შეგვეძლოს მისი ნაწილი ვიყოთ, პირველ რიგში, აუცილებელია, ზედმიწევნით გვესმოდეს ის ფუნდამენტები, რაც დგას ამ ტექნოლოგიების უკან და როგორ შეგვიძლია მათი გამოყენებით მივიდეთ სასურველ პრაქტიკულ შედეგებამდე - ამაში დაგვეხმარებიან სფეროს სპეციალისტები, რომლებიც, თეორიულ ცოდნასთან ერთად, გაგვიზიარებენ თავიანთ ყოველდღიურ საქმიანობებს მონაცემთა მეცნიერების და ხელოვნური ინტელექტის მიმართულებით.
