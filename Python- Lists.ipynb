# %% [markdown]
# ცვლადებში შეგვიძლია შევინახოთ როგორც ერთი მონაცემი, ასევე მონაცემთა ნაკრები. ამის ერთ-ერთი საშუალებაა სიები - lists. list წარმოადგენს მონაცემთა ტიპს, რომელიც ინახავს ელემენტთა ნაკრებს. სიის შესაქმნელად ვიყენებთ კვადრატულ ფრჩხილებს. მაგალითად, შევქმნათ რიცხვების სია:

# %%
a = [1, 2, 3, 4]

# %%
print(a)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# აუცილებელი არ არის, რომ სიაში მხოლოდ ერთი ტიპის მონაცემები იყოს. მასში შეგვიძლია შევინახოთ სხვადასხვა ტიპის მონაცემები ერთდროულად:

# %%
b = [1, 2, 3, "Hello"]

# %%
print(b)
# Out:
# [1, 2, 3, 'Hello']

# %%
b.append("Goodbye")

# %%
print(b)
# Out:
# [1, 2, 3, 'Hello', 'Goodbye']

# %%
b.pop()
# Out:
# 'Goodbye'

# %%
print(b)
# Out:
# [1, 2, 3, 'Hello']

# %%
c = [1, 2, "Hello"]

# %%
print(c[1])
# Out:
# 2

# %%
print(c[0])
print(c[1])
print(c[2])
# Out:
# 1
# 2
# Hello

# %%
print(c[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(c[3])
#
# NameError: name 'c' is not defined

# %%
c = [1, 2, "Hello"]

# %%
c[0] = c[2]
c[2] = c[0]

# %%
print(c)
# Out:
# ['Hello', 2, 'Hello']

# %%
c = [1, 2, "Hello"]

# %%
temp = c[0]
c[0] = c[2]
c[2] = temp

# %%
print(c)
# Out:
# ['Hello', 2, 1]
