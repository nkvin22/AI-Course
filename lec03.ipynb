# %% [markdown]
# # ალბათობა

# %% [markdown]
# რაიმეს მოხდენის შანსი, ანუ რამდენად მოსალოდნელია, რომ რაიმე მოხდება.
#  როდესაც ზუსტად არ ვიცით, რა შედეგს მოიტანს მოვლენა, შეგვიძლია, თითოეული შედეგის დადგომის ალბათობაზე ვისაუბროთ.

# %% [markdown]
# Ამის საილუსტრაციოდ ყველაზე პრიმიტიული მაგალითი არის მონეტის აგდება: Მონეტის აგდების შედეგად, შესაძლო შედეგი მხოლოდ ორია—ან გერბი მოვა, ან -საფასური. ინტუიუტირიუადაც გასაგებია, რომ ამ მოვლენის ალბათობა ერთი მეორედია, ანუ, 50% - მოდი, ვთქვათ, საიდან მოდის ეს რიცხვი:

# %% [markdown]
# ### P = #ვარიანტები, რომლებიც ჩვენ გვაწყობს/#ყველა შესაძლო ვარიანტი
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ანალოგიური პრიმიტიული მაგალითია კამათლის გაგორება: ამ შემთხვევაში სულ ექვსი განსხვავებული შედეგი შეიძლება მივიღოთ, შესაბამისად, მარტივად შეგვიძლია გამოვითვალოთ 1-ის გაგორების; 1-ის ან 6-ის გაგორების; ლუწი რიცხვის გაგორების ალბათობა და ა.შ.

# %% [markdown]
# ####Დამოუკიდებელი და დამოკიდებული ალბათობები
#
# როცა ვანგარიშობთ ერთი და მეორე ხდომილობის მოხდენის ალბათობას, ვამრავლეებთ მათ ალბათობებს. ზოგიერთ შემთხვევაში, პირველი ხდომილობის მოხდენა გავლენას ახდენს მეორე ხდომილობის ალბათობაზე. ამათ ვუწოდებთ დამოკიდებულ ხდომილობებს.
# სხვა შემთხვევებში, პირველი ხდომილობის მოხდენა გავლენას არ ახდენს მეორეს ალბათობაზე. ამათ ვუწოდებთ დამოუკიდებულ ხდომილობებს.
# დამოუკიდებელი ხდომილობები: მონეტის ორჯერ აგდება
# რას უდრის თანაბარი მონეტის ორჯერ აგდებისას ზედიზედ ორჯერ „ავერსის“ მოსვლის ალბათობა? ანუ, რას უდრის პირველი აგდებისასაც და მეორე აგდებისასაც ავერსის მოსვლის ალბათობა?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  Ტოტების ალბათობებს ვამრავლებთ, რომ ვიპოვოთ მომდევნო ხდომილების მოხდენის საერთო ალბათობა. Მაგალითად, ორჯერ საფასურის მოსვლის ალბათობა იქნებოდა:
#   P(T და T) = ½ * ½ = 1/4
# როცა ორი ხდომილება დამოუკიდებელია, შეგვიძლია ვთქვათ, რომ
#
# ###P(A და B) = P(A) * P(B)

# %% [markdown]
# მსგავსი სტრატეგიის გამოყენება შეიძლება დამოკიდებული ალბათობების გამოთვლისასაც. Სტანდარტული 52-ბანქოიანი დასტიდან ორი კარტის ამოღების შემთხვევაში, რა არის ალბათობა იმის, რომ ორივე ამოღებული კარტი შავი ფერის იქნება? ალბათობა იმისა, რომ მეორე კარტი შავი ფერის იქნება იცვლება იმის მიხედვით, პირველი ამოღებული კარტი შავი ფერის იყო თუ თეთრის - ამიტომ ეს ალბათობა პირველზე დამოკიდებულია.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# P(ორივე შავი) = 26/52 * 25/51 ~ 0,245

# %% [markdown]
# ნებისმიერი ორი ხდომილობისთვის შეგვიძლია ვთქვათ, რომ
# ### P(A და B) = P(A) * P(B|A)

# %% [markdown]
# P(B|A) ნიშნავს “თუ მოცემულია, რომ”-ს. Ანუ B ს ალბათობა იმ პირობაში, როცა A უკვე მოხდა. ანუ, Თუ ხდომილებები დამოუკიდებელია, P(B|A) = P(B)

# %% [markdown]
# ---
#
#
# ## ტერმინოლოგია და ძირითადი ფორმულები:
#
# *   ექსპერიმენტი (experiment): ნებისმიერი პროცესი, რომელსაც შეიძლება ერთზე მეტი შესაძლო შედეგი მოჰყვეს.
# *    ელემენტარულ ხდომილობათა სივრცე (Sample Space) : ყველა შესაძლო ექსპერიმენტის შედეგი

# %% [markdown]
# - სიმრავლის დამატება (Complement of events): event $ A' $ is the event consisting of everything in the sample space $S$ that is not contained within $A$
# \begin{equation}
#     P(A) + P(A ') = 1
# \end{equation}

# %% [markdown]
# ### სიმრავლეების გადაკვეთა:

# %% [markdown]
# - Intersections of Events: $A \cap B$ consists of the outcomes contained within both events $A$ and $B$
# - Probability of the intersection, $P(A \cap B) $, is the probability that both events occur simultaneously
# - Properties:
#     - $P(A \cap B) +P(A \cap B') = P(A)$
#     - Mutually exclusive events: if $A \cap B = \emptyset$
#     - $A \cap (B \cap C) = (A \cap B) \cap C $

# %% [markdown]
# ### სიმრავლეების გაერთიანება:

# %% [markdown]
# - Union of Events: $ A \cup B $ consists of the outcomes that are contained within at least one of the events $A$ and $B$
# - The probability of this event, $P (A \cup B)$ is the probability that at least one of these events $A$ and $B$ occurs

# %% [markdown]
# ### პირობითი ალბათობა (conditional probability) :

# %% [markdown]
# Probability of an event $A$ conditional on an event $B$ is:
# \begin{equation}
#     P(A \mid B) = \frac{P(A \cap B)}{P(B)} \hspace{0.5cm}  \text{for } P(B) >0
# \end{equation}

# %% [markdown]
# ### გამრავლების ზოგადი წესი:

# %% [markdown]
# - $P (A \mid B) = \frac{P(A \cap B)}{P(B)} \\
# \Longrightarrow P(A \cap B) = P(B)P (A \mid B)$
# - $P (A \mid B \cap C) = \frac{P(A \cap B \cap C)}{P(B \cap C)} \\
# \Longrightarrow P(A \cap B \cap C) = P(B \cap C)P (A \mid B \cap C)$
# - In general, for a sequence of events $A_1, A_2, \cdots,Untitled A_n$:
# \begin{equation}
#     P(A_1, A_2, \cdots, A_n) = P(A_1)P(A_2 \mid A_1)P(A_3 \mid A_1 \cap A_2) \cdots P(A_n \mid A_1 \cap \cdots \cap A_{n-1})
# \end{equation}

# %% [markdown]
# ### დამოუკიდებელი ხდომილობები:

# %% [markdown]
# - ორი ხდომილება $A$ and $B$ დამოუკიდებელია, თუ:
#     1. $P(A \mid B) = P(A)$
#     2. $P(B \mid A) = P(B)$
#     3. $P(A \cap B) = P(A)P(B)$

# %% [markdown]
# ### გამრავლების ზოგადი წესი:

# %% [markdown]
# - Given $\{ A_1, A_2, \cdots, A_n \}$ a partition of sample space $S$, the probability of an event $B$, $P(B)$ can be expressed as:
# \begin{equation}
#     P(B) = \sum_{i=1}^n P(A_i)P(B \mid A_i)
# \end{equation}

# %% [markdown]
# ### ბაიესის ფორმულა:

# %% [markdown]
# - Given $\{ A_1, A_2, \cdots, A_n \}$ a partition of a sample space, then the posterior probabilities of the event $A_i$ conditional on an event $B$ can be obtained from the probabilities $P(A_i)$ and $P(A_i \mid B)$ using the formula:
# \begin{equation}
#     P(A_i \mid B) = \frac{P(A_i)P(B \mid A_i)}{\sum_{j=1}^n P(A_j)P(B \mid A_j)}
# \end{equation}

# %% [markdown]
# Ასევე, წარმოვიდგინოთ, რომ ფეხბურთის არაფერი გაგეგებათ, და მხოლოდ ის იცით, რომ ან წითელმა გუნმდა უნდა გაიმარჯვოს ან ლურჯმა გუნდმა (ფრე ვერ დამთავრდება); რა იქნებოდა თქვენთვის წითელი გუნდის გამარჯვების ალბათობა მხოლოდ ამ ინფორმაციით?

# %% [markdown]
# ---
# ### თეორიული VS ექსპერიმენტული ალბათობა

# %% [markdown]
# ლოგიკურად, 50 %.
#
# Ახლა ვთქვათ, შეგატყობინეს, რომ წითელი გუნდი ბოლო მსოფლიო ჩემპიონია და ლურჯ გუნდს რამდენიმე TOP მოთამაშე არ ჰყავს; როგორ შეიცვლებოდა ამ შემთხვევაში თქვენი პროგნოზი?

# %% [markdown]
# ლოგიკური იქნება, რომ თქვენი პროგნოზი შეიცვალოს და წითელი გუნდის მოგებისკენ გადაიხაროთ, თუნდაც 51 %ით.

# %% [markdown]
# Თამაშის დასრულებამდე 5 წუთია დარჩენილი და ლურჯი გუნდი იგებს - შეიცვლება თუ არა ამ შემთხვევაში თქვენი მიმდინარე პროგნოზი ?
#
# წესით, უნდა შეიცვალოს.

# %% [markdown]
# Ნიშნავს თუ არა ეს იმას, რომ თქვენი თავდაპირველი პროგნოზი არასწორი იყო?
#
# **არა**

# %% [markdown]
# 💡Მხოლოდ დამდგარი შედეგი ვერ გვიჩვენებს, იყო თუ არა ალბათობა არასწორად განსაზღვრული.
#
# 💡Როდესაც ჩვენ ვიგებთ ახალ ინფორმაციას, ჩვენ უნდა გვქონდეს მზაობა ჩვენი პროგნოზის შესაცვლელად.

# %% [markdown]
# Თეორიულია ალბათობაა, როცა ვამბობთ, რომ კამათლის გაგორებისას 5იანის ამოსვლის ალბათობა ⅙-ია. Ეს ისეთი “
# “Პრიმიტიული” ამოცანაა, რომელშიც სხვა გარე ფაქტორები არ მონაწილეობს და შეგვიძლია ფორმულით ვიხელმძღანელოთ, ასეთი პრიმიტიული ამოცანებია მაგალითად კამათლის გაგორების ან მონეტის აგდების შესაძლო შედეგების და მათი ალბათობების დათვლა: მაგ. დარწმუნებით შეგვიძლია ვთქვათ, რომ კამათელზე 5-იანის მოსვლის ალბათობა 1/6-ია, მაგრამ ნიშნავს თუ არა ეს იმას, რომ 6-ჯერ რომ გავაგოროთ კამათელი, აუცილებლად 1-ხელ ამოვა 5-იანი? Ან ის, რომ მონეტის აგდებისას საფასურის ამოსვლის ალბათობა არის ½, ნიშნავს თუ არა იმას რომ 10 აგდებიდან 5 საფასური ამოვა? -ცხადია, არა, ეს უბრალოდ გვიჩვენებს იმას, თუ რამდენად ალბათურია ამა თუ იმ შედეგის დადგომა, და რომ ძალიან ბევრი ექსპერიმენტის ჩატარების შემთხვევაში, ყოველთვის ამ თანაფარდობასთან მივალთ:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://flipsimu.com/ - ეს არის მონეტის აგდების სიმულატორი, სადაც შეგიძლიათ, რომ ძალიან ბევრჯერ ააგდოთ მონეტა. Ბევრჯერ აგდების შემთხვევაში თქვენი თანაფარდობა უნდა მიუახლოვდეს ½-ს.

# %% [markdown]
# Ექსპერიმენტულ ალბათობას თეორიულისგან განსხვავებით სჭირდება ექსპერიმენტები და სტატისტიკა. Მაგალითად, თუ გვინდა გავიგოთ ალბათობა იმისა, ხვიჩა კვარაცხელია გოლს გაიტანს თუ არა შემდეგ მატჩში, საჭირო იქნება თამაშების სტატისტიკა: მაგალითად, თუ ავიღებთ 20 თამაშის შედეგს, და დავინახავთ, რომ მან 15 თამაშში გაიტანა და 5ში ვერა, დაახლოებით ვიტყვით რომ 15/20 = ⅗ ია ალბათობა რომ შემდეგ მატჩში გაიტანს, მაგრამ ეს პროგნოზი ძალიან სუსტი იქნება  - 		რატომ?

# %% [markdown]
# იმიტომ, რომ რეალურ ცხოვრებაში
