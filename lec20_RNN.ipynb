# %% [markdown]
# # რეკურენტული ნეირონული ქსელი (RNN)

# %% [markdown]
# გეგმა:
# * მიმდევრობითი მონაცემები
# * კლასიკური ღრმა ნეირონული ქსელის პრობლემები
# * რეკურენტული ნეირონული ქსელი
# * RNN ბლოკის დეტალური აღწერა
# * ძირითადი პრობლემები და მოდელის არქიტექტურის მინუსები
# * GRU როგორც პრობლემის დროებითი გადაჭრა

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# RNN -ის პრობლემები:
#
# გვაქვს ნამრავლები, რომლებიც დროში “უკან მიდის”,
# როცა -ების მნიშვნელობები მცირეა და  დიდი მაშინ
# გრადიენტის გაქრობასთან გვაქვს საქმე
#
# გრადიენტები შეიძლება გაქრეს ან გაფეთქდეს გრძელვადიანი
# დამოკიდებულებების გამო, რაც აფერხებს სწავლების პროცესს

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
